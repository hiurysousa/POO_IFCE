# %%
# 1) Crie uma classe LivroDigital com atributos titulo autor formato.
# Implemente metodo baixar e exibir_informacoes do livro.

# %%
# 2) Desenvolva classe Carro com marca modelo ano e quilometragem.
# Adicione metodos dirigir e calcular_consumo de combustivel.

# %%
# 3) Implemente classe Aluno com nome matricula curso e notas.
# Crie metodo calcular_media e verificar_aprovacao do aluno.

# %%
# 4) Crie classe Tarefa com descricao data prazo e status.
# Adicione metodos marcar_concluida e exibir_detalhes da tarefa.

# %%
# 5) Desenvolva classe Restaurante com nome endereco tipo e capacidade
# Implemente metodos reservar_mesa e exibir_cardapio do restaurante.

# %%
# 6) Classe de entidade para representar um filme no sistema.
# Atributos: titulo, diretor, duracao e genero. Implemente o construtor.
# Método exibir_info: mostra todos os dados formatados do filme.
# Crie dois objetos de filmes diferentes para testar a classe.
# Avalie se o método exibir_info funciona para ambos os casos.

# %%
# 7) Classe de configuração chamada AppConfig para armazenar dados globais.
# Atributos de classe: nome_app, versao, idioma_padrao e ambiente_execucao.
# Não instancie esta classe, use apenas os atributos diretamente.
# Exiba o nome do aplicativo e a versão no console.
# Verifique se o idioma padrão está definido como português.

# %%
# 8) Classe de serviço NotificacaoService para gerenciar envio de mensagens.
# Atributo: historico (lista). Método enviar_email recebe destinatario e mensagem.
# O método deve adicionar o email ao histórico de envios.
# Método listar_enviados: percorre e exibe todos os emails da lista.
# Instancie o serviço e simule o envio de três emails.

# %%
# 9) Classe utilitária Conversor para operações matemáticas de unidades medida.
# Métodos estáticos: celsius_para_fahrenheit, metros_para_centimetros e quilos_para_gramas.
# Cada método deve receber um valor e retornar calculado.
# Use @staticmethod para definir cada uma das funções utilitárias.
# Teste as conversões chamando a classe sem criar um objeto.

# %%
# 10) Classe abstrata chamada Animal usando o módulo abc do Python.
# Atributos: nome e idade. Método abstrato chamado emitir_som().
# Método comum chamado dormir que exibe uma mensagem padrão.
# Tente instanciar a classe Animal e explique o erro ocorrido.
# Crie uma subclasse Cachorro que implementa o método emitir_som.

# %%
# 11) Explique a diferença visual entre atributos públicos, protegidos e privados.
# Atributos públicos não possuem prefixo. Protegidos usam um underline (_).
# Atributos privados utilizam dois underlines (__) no início do nome.
# Como o Python trata o acesso externo para cada um deles?
# Implemente uma classe Teste que demonstre essas três formas diferentes.

# %%
# 12) Crie a classe ContaBancaria com o atributo privado chamado __saldo.
# Use o decorador @property para criar um getter para saldo.
# Crie um @saldo.setter que impeça depósitos de valores negativos.
# Lance um ValueError caso o valor informado seja menor que zero.
# Teste a proteção tentando atribuir um valor inválido ao saldo.

# %%
# 13) Implemente a classe Sensor com um método privado __calibrar_sistema.
# O método deve apenas imprimir uma mensagem de calibração interna.
# Crie um método público chamado ligar que executa a calibração.
# Tente chamar o método __calibrar_sistema diretamente fora da classe.
# Explique por que o Python impede essa chamada direta no código.

# %%
# 14) Crie uma classe Perfil com atributo protegido _email do usuário.
# Implemente validação no setter para garantir que o email contenha @.
# O atributo deve ser inicializado pelo construtor usando o setter.
# Crie um objeto e tente alterar o email para inválido.
# Verifique se a exceção é lançada corretamente pelo seu código.

# %%
# 15) Modele uma classe ControleRemoto com o atributo privado __volume atual.
# Crie métodos aumentar_volume e diminuir_volume para alterar o valor privado.
# O volume deve estar sempre entre a faixa de 0-100.
# Use @property para permitir apenas a leitura do volume atual.
# Impeça que o usuário altere o volume sem usar métodos.
